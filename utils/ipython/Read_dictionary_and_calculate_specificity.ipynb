# %%
import numpy as np
import os
import pickle

# %%
main_dirctory = "../../data/data_generated_medicotask_70_30_modified_v3/pytorch_history/"

file_name = "24_3_cm_dictionary.pkl"

# %%
file_name_20_5 = "20_5_cm_dictionary.pkl"

# %%
file_name_23_2 = "23_2_cm_dictionary.pkl"

# %%
#os.listdir(main_dirctory)

# %%
# read_dictionary = np.load(os.path.join(main_dirctory, file_name))

# %% [markdown]
# # Method 5 - Informations

# %%
f = open(os.path.join(main_dirctory, file_name), "rb")

# %%
dt = pickle.load(f)

# %%
type(dt)
# Out:
# pandas.core.frame.DataFrame

# %%
dt
# Out:
# Classes                                       0            1           2   \
# Population                                  1598         1598        1598
# P: Condition positive                         53           81         138
# N: Condition negative                       1545         1517        1460
# Test outcome positive                         53           82         133
# Test outcome negative                       1545         1516        1465
# TP: True Positive                             53           81         130
# TN: True Negative                           1545         1516        1457
# FP: False Positive                             0            1           3
# FN: False Negative                             0            0           8
# TPR: (Sensitivity, hit rate, recall)           1            1    0.942029
# TNR=SPC: (Specificity)                         1     0.999341    0.997945
# PPV: Pos Pred Value (Precision)                1     0.987805    0.977444
# ...

# %%
np_array= dt.iloc[10].values

# %%
np.average(np_array)
# Out:
# 0.997150028248746

# %% [markdown]
# # Method 3- Informations (20_5)

# %%
f = open(os.path.join(main_dirctory, file_name_20_5), "rb")

# %%
dt_20_5 = pickle.load(f)

# %%
np_20_5 = dt_20_5.iloc[10].values

# %%
np.average(np_20_5)
# Out:
# 0.9968555962294117

# %% [markdown]
# # Method 4 - Informations (23_2)

# %%
f = open(os.path.join(main_dirctory, file_name_23_2), "rb")

# %%
dt_23_2 = pickle.load(f)

# %%
np_23_2 = dt_23_2.iloc[10].values

# %%
np.average(np_23_2)
# Out:
# 0.9969785294470557
