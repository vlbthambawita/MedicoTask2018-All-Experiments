# %%
import os
import shutil

# %%
train_data_dir = "/home/vajira/simula/code_samples/mediaEval_2018_structured_v2/data/data_modified_polyps_non_polyps/train"

# %%
os.listdir(train_data_dir)
# Out:
# ['stool-plenty',
#  'normal-z-line',
#  'colon-clear',
#  'non-polyps',
#  'retroflex-rectum',
#  'dyed-lifted-polyps',
#  'instruments',
#  'normal-pylorus',
#  'stool-inclusions',
#  'blurry-nothing',
#  'out-of-patient',
#  'esophagitis',
#  'retroflex-stomach',
#  'ulcerative-colitis',
#  'polyps',
#  'dyed-resection-margins',
#  'normal-cecum']

# %%
os.listdir(os.path.join(train_data_dir, "stool-plenty"))
# Out:
# ['171.jpg',
#  '5.jpg',
#  '173.jpg',
#  '225.jpg',
#  '139.jpg',
#  '266.jpg',
#  '57.jpg',
#  '131.jpg',
#  '181.jpg',
#  '342.jpg',
#  '152.jpg',
#  '16.jpg',
#  '260.jpg',
#  '362.jpg',
#  '93.jpg',
#  '100.jpg',
#  '168.jpg',
#  '67.jpg',
#  '6.jpg',
#  '287.jpg',
#  '208.jpg',
#  '359.jpg',
#  '102.jpg',
#  '360.jpg',
#  '221.jpg',
#  '311.jpg',
#  '230.jpg',
#  '211.jpg',
#  '329.jpg',
#  '10.jpg',
#  '170.jpg',
#  '242.jpg',
#  '94.jpg',
#  '363.jpg',
#  '133.jpg',
#  '124.jpg',
#  '105.jpg',
#  '295.jpg',
#  '270.jpg',
#  '364.jpg',
#  '58.jpg',
#  '280.jpg',
#  '146.jpg',
#  '122.jpg',
#  '263.jpg',
#  '14.jpg',
#  '111.jpg',
#  '99.jpg',
#  '129.jpg',
#  '255.jpg',
#  '183.jpg',
#  '180.jpg',
#  '243.jpg',
#  '269.jpg',
#  '145.jpg',
#  '361.jpg',
#  '334.jpg',
#  '291.jpg',
#  '53.jpg',
#  '209.jpg',
#  '238.jpg',
#  '31.jpg',
#  '21.jpg',
#  '154.jpg',
#  '257.jpg',
#  '307.jpg',
#  '200.jpg',
#  '120.jpg',
#  '12.jpg',
#  '186.jpg',
#  '13.jpg',
#  '69.jpg',
# ...

# %%
# copying images of train directory to the non
for i in os.listdir(os.path.join(train_data_dir, "stool-plenty")):
    shutil.move()
